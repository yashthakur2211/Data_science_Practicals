# %%
# Name Yash Thakur
# Roll No. B - 75
# DS - Assignment - 1

# %%
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# Out:
# ...
#      ---------------------------------------- 0.0/160.8 kB ? eta -:--:--
#      --------- --------------------------- 41.0/160.8 kB 653.6 kB/s eta 0:00:01
#      ------------------------------------ - 153.6/160.8 kB 1.5 MB/s eta 0:00:01
#      -------------------------------------- 160.8/160.8 kB 1.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/7.5 MB 5.2 MB/s eta 0:00:02
#    -- ------------------------------------- 0.4/7.5 MB 4.6 MB/s eta 0:00:02
#    --- ------------------------------------ 0.7/7.5 MB 4.6 MB/s eta 0:00:02
#    ---- ----------------------------------- 0.8/7.5 MB 4.3 MB/s eta 0:00:02
#    ----- ---------------------------------- 1.0/7.5 MB 4.4 MB/s eta 0:00:02
#    ------ --------------------------------- 1.2/7.5 MB 4.2 MB/s eta 0:00:02
#    ------- -------------------------------- 1.3/7.5 MB 4.0 MB/s eta 0:00:02
# ...

# %%
import pandas as pd
import numpy as np

# %%
# read CSV File(comma seperated values)
df = pd.read_csv('goldstock.csv')

# %%
# Display whole dataset
print(df.to_string())
# Out:
#       Unnamed: 0        Date   Close    Volume    Open    High     Low
# 0              0  2024-01-19  2029.3  166078.0  2027.4  2041.9  2022.2
# 1              1  2024-01-18  2021.6  167013.0  2009.1  2025.6  2007.7
# 2              2  2024-01-17  2006.5  245194.0  2031.7  2036.1  2004.6
# 3              3  2024-01-16  2030.2  277995.0  2053.4  2062.8  2027.6
# 4              4  2024-01-12  2051.6  250946.0  2033.2  2067.3  2033.1
# 5              5  2024-01-11  2019.2  270624.0  2029.4  2056.1  2017.3
# 6              6  2024-01-10  2027.8  183625.0  2036.0  2046.2  2025.9
# 7              7  2024-01-09  2033.0  194610.0  2034.5  2048.6  2031.9
# 8              8  2024-01-08  2033.5  199325.0  2052.6  2053.3  2022.7
# 9              9  2024-01-05  2049.8  208861.0  2051.4  2071.1  2030.8
# 10            10  2024-01-04  2050.0  125573.0  2049.3  2058.1  2043.3
# 11            11  2024-01-03  2042.8  214132.0  2067.9  2074.3  2038.3
# ...

# %%
# prints values in Dataset
print(df.values)
# Out:
# [[0 '2024-01-19' 2029.3 ... 2027.4 2041.9 2022.2]
#  [1 '2024-01-18' 2021.6 ... 2009.1 2025.6 2007.7]
#  [2 '2024-01-17' 2006.5 ... 2031.7 2036.1 2004.6]
#  ...
#  [2530 '2014-01-24' 1264.5 ... 1264.3 1273.2 1256.9]
#  [2531 '2014-01-23' 1262.5 ... 1235.1 1267.1 1230.8]
#  [2532 '2014-01-22' 1238.6 ... 1240.5 1243.5 1235.5]]

# %%
# Gives datatype of data
print(df.dtypes)
# Out:
# Unnamed: 0      int64
# Date           object
# Close         float64
# Volume        float64
# Open          float64
# High          float64
# Low           float64
# dtype: object

# %%
# Return True for not null values
df.notnull()
# Out:
#       Unnamed: 0  Date  Close  Volume  Open  High   Low
# 0           True  True   True    True  True  True  True
# 1           True  True   True    True  True  True  True
# 2           True  True   True    True  True  True  True
# 3           True  True   True    True  True  True  True
# 4           True  True   True    True  True  True  True
# ...          ...   ...    ...     ...   ...   ...   ...
# 2506        True  True   True    True  True  True  True
# 2507        True  True   True    True  True  True  True
# 2508        True  True   True    True  True  True  True
# 2509        True  True   True    True  True  True  True
# 2510        True  True   True    True  True  True  True
#
# [2511 rows x 7 columns]

# %%
# Return true for Null Values
df.isnull()
# Out:
#       Unnamed: 0   Date  Close  Volume   Open   High    Low
# 0          False  False  False   False  False  False  False
# 1          False  False  False   False  False  False  False
# 2          False  False  False   False  False  False  False
# 3          False  False  False   False  False  False  False
# 4          False  False  False   False  False  False  False
# ...          ...    ...    ...     ...    ...    ...    ...
# 2506       False  False  False   False  False  False  False
# 2507       False  False  False   False  False  False  False
# 2508       False  False  False   False  False  False  False
# 2509       False  False  False   False  False  False  False
# 2510       False  False  False   False  False  False  False
#
# [2511 rows x 7 columns]

# %%
# Drops rows and columns of null values 
df.dropna()
# Out:
#       Unnamed: 0        Date   Close    Volume    Open    High     Low
# 0              0  2024-01-19  2029.3  166078.0  2027.4  2041.9  2022.2
# 1              1  2024-01-18  2021.6  167013.0  2009.1  2025.6  2007.7
# 2              2  2024-01-17  2006.5  245194.0  2031.7  2036.1  2004.6
# 3              3  2024-01-16  2030.2  277995.0  2053.4  2062.8  2027.6
# 4              4  2024-01-12  2051.6  250946.0  2033.2  2067.3  2033.1
# ...          ...         ...     ...       ...     ...     ...     ...
# 2506        2528  2014-01-28  1250.5   81426.0  1254.9  1261.9  1248.0
# 2507        2529  2014-01-27  1263.5   63419.0  1269.9  1280.1  1252.0
# 2508        2530  2014-01-24  1264.5   34998.0  1264.3  1273.2  1256.9
# 2509        2531  2014-01-23  1262.5   41697.0  1235.1  1267.1  1230.8
# 2510        2532  2014-01-22  1238.6   80262.0  1240.5  1243.5  1235.5
#
# [2511 rows x 7 columns]

# %%
# plots data in histogram
df.plot()
# Out:
# <Axes: >
