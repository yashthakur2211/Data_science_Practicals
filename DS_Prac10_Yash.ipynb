# %%
import pandas as pd
import numpy as np

# %%
data  = pd.read_csv('Downloads/iris.csv')
data
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm    Species  \
# 0    1            5.1           3.5            1.4           0.2  Virginica
# 1    2            4.9           3.0            1.4           0.2  Virginica
# 2    3            4.7           NaN            1.3           0.2  Virginica
# 3    4            4.6           3.1            1.5           0.2  Virginica
# 4    5            5.0           3.6            1.4           0.2  Virginica
# 5    6            0.0           NaN            NaN           0.4     Setosa
# 6    7            4.6           3.4            1.4           0.3     Setosa
# 7    8            5.0           3.4            1.5           0.2     Setosa
# 8    9            4.4           2.9            1.4           0.2     Setosa
# 9   10            4.9           3.1            1.5           0.1     Setosa
# 10  10            4.9           3.1            1.5           0.1     Setosa
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             17 non-null     int64
#  1   SepalLengthCm  16 non-null     float64
#  2   SepalWidthCm   15 non-null     float64
#  3   PetalLengthCm  15 non-null     float64
#  4   PetalWidthCm   17 non-null     float64
#  5   Species        17 non-null     object
#  6   order          17 non-null     int64
# dtypes: float64(4), int64(2), object(1)
# memory usage: 1.1+ KB

# %%
column = len(list(data))
column
# Out:
# 7

# %%
np.unique(data['Species'])
# Out:
# array(['Setosa', 'Virginica', 'verseta'], dtype=object)

# %%
data.describe()
# Out:
#               Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count  17.000000       16.00000     15.000000      15.000000     17.000000
# mean    8.529412        4.63750      3.346667       1.380000      0.194118
# std     4.529316        1.30837      0.360291       0.126491      0.074755
# min     1.000000        0.00000      2.900000       1.100000      0.100000
# 25%     5.000000        4.60000      3.050000       1.350000      0.200000
# 50%     9.000000        4.90000      3.400000       1.400000      0.200000
# 75%    12.000000        5.02500      3.550000       1.500000      0.200000
# max    15.000000        5.80000      4.000000       1.500000      0.400000
#
#            order
# count  17.000000
# mean    2.352941
# std     1.411612
# min     1.000000
# 25%     1.000000
# 50%     2.000000
# 75%     3.000000
# max     6.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))

axes[0,0].set_title('First Column Graph')
axes[0,0].hist(data['SepalLengthCm'])

axes[0,1].set_title('Second column Graph')
axes[0,1].hist(data['SepalWidthCm'])

axes[1,0].set_title('Third Column Graph')
axes[1,0].hist(data['PetalLengthCm'])

axes[1,1].set_title('Fourth Column Graph')
axes[1,1].hist(data['PetalWidthCm'])
# Out:
# (array([ 4.,  0.,  0., 11.,  0.,  0.,  1.,  0.,  0.,  1.]),
#  array([0.1 , 0.13, 0.16, 0.19, 0.22, 0.25, 0.28, 0.31, 0.34, 0.37, 0.4 ]),
#  <BarContainer object of 10 artists>)
